# %%
import os, pandas as pd, colorcet as cc
from bokeh.transform import factor_cmap
from bokeh.plotting import save, output_file, figure, show
from bokeh.models import ColumnDataSource, HoverTool, Range1d, Legend, LegendItem

# %%
df = pd.read_parquet('labeled_samples/grocery_labeled_sample.parquet')

# %%
list_x = df.c2.tolist()
list_y = df.c1.tolist()
labels_ = df.label.tolist()
desc = (df.product_title.astype(str) + ' ' + df.review).to_list()

output_file(filename='grocery_embeddings.html', title='Grocery Embeddings')

source = ColumnDataSource(data=dict(x=list_x, y=list_y, desc=desc, clustering=labels_))

hover = HoverTool(
    tooltips=[
        ('index', '$index'),
        ('(x,y)', '(@x, @y)'),
        ('desc', '@desc')
        ]
    )

f = figure(width=800, height=800, tools=[hover, 'pan, wheel_zoom, reset'])
f.title.text = 'UMAP Applied to a Random Sample of 100,000 Grocery Reviews'
f.title.text_font_size = '15px'
f.title.align = 'center'

f.scatter('x', 'y', source=source, size=1, color='navy', alpha=0.5)

save(f)
# Out:
# 'c:\\Users\\E079051\\Desktop\\Product_Reviews_Analysis\\grocery_embeddings.html'

# %%
df['legend_rank'] = df.label.map(df.label.value_counts().to_dict())

# %%
df.sort_values('legend_rank', ascending=False, inplace=True)

# %%
labels = df.label.tolist()
desc = (df.product_title.astype(str) + ' ' + df.review).to_list()

output_file(filename='grocery_clusters.html', title='Grocery Clusters')

source = ColumnDataSource(
    data=dict(
        x=df.c2.tolist(), 
        y=df.c1.tolist(), 
        desc=desc, 
        labels=labels
        )
    )

hover = HoverTool(
    tooltips=[
        ('index', '$index'),
        ('(x,y)', '(@x, @y)'),
        ('desc', '@desc')
        ]
    )

f = figure(width=935, height=800, tools=[hover, 'pan, wheel_zoom, reset'])
f.title.text = 'HDBSCAN Applied to UMAP Embeddings. Clusters Labeled Using YAKE'
f.title.text_font_size = '15px'
f.title.align = 'center'

mapper = factor_cmap(
    field_name='labels',
    palette=['#EEEEEE']+cc.glasbey[:len(set(labels))], 
    factors=['unclustered']+list(set(labels))
    )

f.add_layout(Legend(), 'right')
f.scatter('x', 'y', legend_group='labels', source=source, size=1, color=mapper, alpha=0.7)
# f.legend.visible = False

# legend_items = f.legend.items
# legend = Legend(items=legend_items[:9], location=(115,1))
# f.add_layout(legend, 'center')
# legend = Legend(items=legend_items[9:18], location=(218,1))
# f.add_layout(legend, 'center')
# legend = Legend(items=legend_items[18:27], location=(318,1))
# f.add_layout(legend, 'center')
# legend = Legend(items=legend_items[27:36], location=(411,1))
# f.add_layout(legend, 'center')
# legend = Legend(items=legend_items[36:43], location=(518,70))
# f.add_layout(legend, 'center')

show(f)

# %%
files = [file for file in os.listdir('data')]

# %%
def get_verified_purchase_stats(file):
    df1 = pd.read_parquet(f'data/{file}')
    total_count = df1.shape[0]
    verified_count = (df1.verified_purchase == 'Y').sum()
    # print('-'*10, file, '-'*10)
    # print(f'Verified purchase count: {verified_count:,}')
    # print(f'Proportion of total records: {verified_count/df1.shape[0]:,.2%}')
    df2 = df1[df1.verified_purchase == 'Y']
    # print('If we then exclude reviews with helpful votes > 5 ...')
    # helpful_count = (df2.helpful_votes > 5).sum()
    # print(f'... there are {helpful_count:,}')
    # print('If we then exclude reviews having less than 0.9 ratio of helpful to total votes')
    # df3 = df2[df2.helpful_votes > 5]
    # print(f'Final count: {(df3.helpful_votes/df3.total_votes > .9).sum():,}')
    helpful_count = (df2.helpful_votes/df2.total_votes > .8).sum()
    return total_count, verified_count, helpful_count

# %%
import re

# %%
dfs = {}
for file in files:
    name = re.findall('(?<=reviews_)[.\w]*(?=.parq)', file)[0].lower() 
    dfs[name] = get_verified_purchase_stats(file)
    print(name)
# Out:
# apparel
# automotive
# baby
# beauty
# books
# camera
# digital_ebook_purchase
# digital_music_purchase
# digital_software
# digital_video_download
# digital_video_games
# electronics
# furniture
# gift_card
# grocery
# health_personal_care
# major_appliances
# mobile_apps
# mobile_electronics
# multilingual
# music
# musical_instruments
# office_products
# outdoors
# pc
# personal_care_appliances
# pet_products
# shoes
# software
# sports
# tools
# toys
# video
# video_dvd
# video_games
# watches
# wireless

# %%
new_df = pd.DataFrame(dfs).T.rename(columns={0:'total',1:'verified',2:'helpful'})

# %%
new_df
# Out:
#                             total  verified  helpful
# apparel                   5906333   5312781  1009348
# automotive                3514942   3228457   719089
# baby                      1752932   1392128   236822
# beauty                    5115666   4230268   994353
# books                     3105520    229346   130004
# camera                    1801974   1494403   369056
# digital_ebook_purchase    5101693   3942399  1051017
# digital_music_purchase    1688884   1256444   151599
# digital_software           102084     70860    15516
# digital_video_download    4057147   2704502   272787
# digital_video_games        145431    124316    17524
# electronics               3093869   2600230   519700
# furniture                  792113    718192   221235
# gift_card                  149086    136042     3723
# grocery                   2402458   1977803   493796
# health_personal_care      5331449   4448677  1086145
# major_appliances            96901     68843    20359
# mobile_apps               5033376   4788908   736502
# mobile_electronics         104975     88506    17937
# multilingual              6931166   5059401   619103
# music                     4751577   1962373   500480
# musical_instruments        904765    781603   199353
# office_products           2642434   2257895   506016
# outdoors                  2302401   2025958   479991
# pc                        6908554   6048852  1051489
# personal_care_appliances    85981     63312    19099
# pet_products              2643619   2323541   551954
# shoes                     4366916   3944830   753568
# software                   341931    195647    50196
# sports                    4850360   4283735   910586
# tools                     1741100   1523728   343163
# toys                      4864249   4021909   802478
# video                      380604     95732    33350
# video_dvd                 5069140   3316054   721970
# video_games               1785997   1169701   168075
# watches                    960872    831415   188101
# wireless                  9002021   7929464  1103686

# %%
((new_df.helpful-new_df.total)/new_df.total*100).mean()
# Out:
# -84.03867906193258

# %%
df.sort_values('helpful_votes', ascending=False).head()
# Out:
#          customer_id       review_id  product_id  product_parent  \
# 2344167     47364506   RXXPVOUH9NLL3  B00032G1S0       753469671
# 923600      29857793  R2DQNJRV27D3P0  B000EVOSE4       990977895
# 2393030     49234072   RKT07YYORZMZE  B00032G1S0       753469671
# 1756395      9286343  R3SC3RFGX29KPJ  B00012182G       554396858
# 249057        809523  R2JGNJ5ZPJT4YC  B000EVOSE4       990977895
#
#                                              product_title  star_rating  \
# 2344167  Tuscan Dairy Whole Vitamin D Milk, Gallon, 128 oz            5
# 923600                      Haribo Gummi Candy Gold-Bears,            5
# 2393030  Tuscan Dairy Whole Vitamin D Milk, Gallon, 128 oz            3
# 1756395                                 Fresh Whole Rabbit            1
# 249057                      Haribo Gummi Candy Gold-Bears,            1
#
#          helpful_votes  total_votes vine verified_purchase review_date  \
# 2344167          23755        24170    N                 N  2008-07-08
# 923600           11045        11901    N                 N  2014-10-22
# 2393030           9986        10304    N                 N  2006-10-30
# 1756395           7886         8076    N                 N  2013-05-10
# 249057            6201         6900    N                 N  2015-06-05
#
#                                                     review
# 2344167  Make this your only stock and store Once upon ...
# 923600   I have seen the face of God. I didn't feel the...
# 2393030  One Friday, Without the Milk He always brought...
# 1756395  Not like Game of Thrones Brad and I were very ...
# 249057   See you in hell, Haribo Sugar-Free Gummi Bears...

# %%
re.findall('(?<=reviews_)[.\w]*(?=.parq)', 'reviews_this_is_a_test.parquet')[0].lower()
# Out:
# 'this_is_a_test'

# %%
df = pd.read_parquet('data/amazon_reviews_gift_card.parquet')

# %%
df[(df.verified_purchase == 'Y') & (df.helpful_votes/df.total_votes > 0.8)]
# Out:
#         customer_id       review_id  product_id  product_parent  \
# 11         23413911  R1XZHS8M1GCGI7  B004KNWWU4       326384774
# 12          2026222  R1DAI0N03SKRJN  B004LLIKVU       473048287
# 14         20241560   RIBOP6OEAZA47  B00H5BNLUS       637715957
# 19         14222739  R196T0NZ73TYIM  B005ESMMKE       459536087
# 32          4788872  R3MHW0ENYJ5FKI  B004LLIKVU       473048287
# ...             ...             ...         ...             ...
# 149006     15348738  R2KPA5J1MXBJSD  B001GXRQW0       246986987
# 149017     41021473  R3M9UKKKPVQVF0  B001H53QDK       246986987
# 149019     52540230  R1XNO68OHJM5SW  B001H53QDK       246986987
# 149036     46747390  R1GLUPO4UO93OS  B000LGKQHU       941684275
# 149044     40992007  R2B0767O26G2N4  B000LGKQHU       941684275
#
#                                             product_title  star_rating  \
# 11      Amazon Gift Card - Print - Happy Birthday (Birds)            5
# 12                                 Amazon.com eGift Cards            5
# 14      Amazon eGift Card - Hoops and Yoyo Thank You V...            5
# 19      Amazon.com Gift Cards, Pack of 10 (Various Car...            5
# 32                                 Amazon.com eGift Cards            5
# ...                                                   ...          ...
# 149006                              Amazon.com Gift Cards            1
# 149017                              Amazon.com Gift Cards            1
# 149019                              Amazon.com Gift Cards            1
# 149036                        Apple iTunes $25 Music Card            5
# 149044                        Apple iTunes $25 Music Card            4
#
#         helpful_votes  total_votes vine verified_purchase review_date  \
# 11                  1            1    N                 Y  2015-08-31
# 12                  1            1    N                 Y  2015-08-31
# 14                  1            1    N                 Y  2015-08-31
# 19                  1            1    N                 Y  2015-08-31
# 32                  1            1    N                 Y  2015-08-31
# ...               ...          ...  ...               ...         ...
# 149006            186          222    N                 Y  2008-12-22
# 149017            576          688    N                 Y  2008-12-15
# 149019            452          545    N                 Y  2008-12-11
# 149036              5            5    N                 Y  2007-03-08
# 149044              5            5    N                 Y  2007-01-09
#
#                                                    review
# 11      Always good Easy to print from email.  I love ...
# 12                      Five Stars Amazing with 10 dollar
# 14                                        Five Stars good
# 19                                        Five Stars nice
# 32                                        Five Stars Good
# ...                                                   ...
# 149006  Card didn't work After I ordered a gift card a...
# 149017  Prime Members BEWARE I am a dedicated Amazon.c...
# 149019  Horrible experience Bought three $50 gift card...
# 149036  Apple iTunes $25 Music card Easy to use. As yo...
# 149044  One thing to know before you buy this: You hav...
#
# [3723 rows x 12 columns]

# %%
dff = df[df.verified_purchase == 'Y']
dff.shape
# Out:
# (136042, 12)

# %%
df3 = dff[dff.total_votes > 2]
df3.shape
# Out:
# (1350, 12)

# %%
df4 = dff[(dff.helpful_votes / dff.total_votes) > .8]
df4.shape
# Out:
# (3723, 12)

# %%
f'{(dff.shape[0]-df.shape[0])/df.shape[0]:,.2%}',\
f'{(df3.shape[0]-dff.shape[0])/dff.shape[0]:,.2%}',\
f'{(df4.shape[0]-df3.shape[0])/df3.shape[0]:,.2%}'
# Out:
# ('-30.59%', '-92.47%', '-41.86%')

# %%
(dff.helpful_votes/dff.total_votes)[dff.helpful_votes/dff.total_votes > .9]
# Out:
# 15        1.000000
# 27        1.000000
# 36        1.000000
# 65        1.000000
# 76        1.000000
#             ...
# 101933    1.000000
# 101944    1.000000
# 101968    0.976744
# 101986    1.000000
# 101989    1.000000
# Length: 14450, dtype: float64

# %%
(dff.helpful_votes/dff.total_votes > .9).sum()
# Out:
# 14450

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS

# %%
df['test1'] = pd.Series(['hello']*df.shape[0], dtype='category')

# %%
df.test1 = df.test1.astype(str)

# %%
import numpy as np

# %%
df[df.star_rating==5].index
# Out:
# Int64Index([    0,     2,     3,     4,     6,     7,     8,     9,    10,
#                14,
#             ...
#             99987, 99989, 99990, 99991, 99992, 99994, 99996, 99997, 99998,
#             99999],
#            dtype='int64', length=69266)

# %%
docs = df.product_title.str[:].copy() + ' ' + df.review.str[:].copy()
sample = docs.sample(min(100000, docs.shape[0]), random_state=1729)

# %%
sample = sample.to_frame().rename(columns={0:'cluster'})

# %%
sample
# Out:
#                                                  cluster
# 68037  Lipton Tea Bags Good Just the right type of te...
# 344    Mad Monkey Coffee Capsules, 48 Count Five Star...
# 68833  Annie's Organic Bunny Fruit Snacks, Variety Pa...
# 69327  MarketSpice Teabags, box of 24 (Market Spice T...
# 22061  Suddenly Pasta Salad Yummy This mix is excelle...
# ...                                                  ...
# 88921  Heinz Reduced Sugar Tomato Ketchup, 13 oz (Pac...
# 54821  Cadbury Easter Creme Egg, 1.2-Ounce Eggs (Pack...
# 66803  CedarHouse Ultra-Premium Cedar Paper Grilling ...
# 68710  Nutiva Hi Fiber Hemp Protein Powder - 16 OZ Go...
# 1677   Darrell Lea Soft Eating Liquorice, 7 Ounce (Pa...
#
# [100000 rows x 1 columns]

# %%
sample['test'] = [np.random.randint(0,100) for i in range(sample.shape[0])]
sample
# Out:
#                                                  cluster  test
# 68037  Lipton Tea Bags Good Just the right type of te...    43
# 344    Mad Monkey Coffee Capsules, 48 Count Five Star...    33
# 68833  Annie's Organic Bunny Fruit Snacks, Variety Pa...    88
# 69327  MarketSpice Teabags, box of 24 (Market Spice T...    28
# 22061  Suddenly Pasta Salad Yummy This mix is excelle...    10
# ...                                                  ...   ...
# 88921  Heinz Reduced Sugar Tomato Ketchup, 13 oz (Pac...    87
# 54821  Cadbury Easter Creme Egg, 1.2-Ounce Eggs (Pack...     6
# 66803  CedarHouse Ultra-Premium Cedar Paper Grilling ...    53
# 68710  Nutiva Hi Fiber Hemp Protein Powder - 16 OZ Go...    59
# 1677   Darrell Lea Soft Eating Liquorice, 7 Ounce (Pa...    18
#
# [100000 rows x 2 columns]

# %%
import pandas as pd

# %%
df = pd.read_parquet('samples/key_topics.parquet')

# %%
df
# Out:
#           labels   bad   good   ranking product_category  \
# 0           baby   430   1461  0.294319          apparel
# 1            bag   198    603  0.328358          apparel
# 2           belt   591   1138  0.519332          apparel
# 3            bra  1623   3184  0.509736          apparel
# 4        costume  1088   2590  0.420077          apparel
# ..           ...   ...    ...       ...              ...
# 910       stylus   275   1340  0.205224         wireless
# 911  unclustered  7634  16791  0.454648         wireless
# 912          usb   445    594  0.749158         wireless
# 913        watch   543    649  0.836672         wireless
# 914     wireless   140    391  0.358056         wireless
#
#                                                bad_set  \
# 0    poorly rough ripped thinner stitching suspende...
# 1    ripped falling useless coming broke poor broke...
# 2    digs fray pin sending home crap disappointing ...
# 3    ahh twisted madonna lying meh factor beware un...
# 4    practically refund junk sending sags god edge ...
# ..                                                 ...
# 910  usable poor falls broken angle version middle ...
# 911  buzzing ending garbled eligible beta deceived ...
# 912  noticed recognized wouldn compatible picture e...
# 913  crap disappointing desired returning lock phot...
# 914  happened multiple based stops flashing pay ret...
#
#                                               good_set
# 0    amazing carters family careful thinking beauti...
# 1    amazing idea easier contents construction plan...
# 2    amazing personally plenty surprise cell catch ...
# 3    blouses heaven duty yay subtle smart expectati...
# 4    expectations dirty warned preferred nicer gart...
# ..                                                 ...
# 910  amazing smartphone process purchases stuff ini...
# 911  stumbled lightly cleaner bows jackery replacea...
# 912  fantastic amazing highly contacted home meant ...
# 913  scratch professional messaging surprised singl...
# 914  amazing grab deal flat kind cases cell larger ...
#
# [915 rows x 7 columns]

# %%
dff = pd.read_parquet('samples/grocery_key_topics.parquet')

# %%
dff
# Out:
#          labels   bad   good   ranking product_category  \
# 0          baby   158    416  0.379808          grocery
# 1          bars   343   1018  0.336935          grocery
# 2         beans   126    538  0.234201          grocery
# 3         bread   101    613  0.164763          grocery
# 4        butter   212    988  0.214575          grocery
# 5         candy   747   2081  0.358962          grocery
# 6        cereal   166   1062  0.156309          grocery
# 7        cheese   171    757  0.225892          grocery
# 8          chia   117    426  0.274648          grocery
# 9         chips   311    957  0.324974          grocery
# 10    chocolate   726   2323  0.312527          grocery
# 11        cocoa   104    547  0.190128          grocery
# 12       coffee  2092   7129  0.293449          grocery
# 13      cookies   427   1281  0.333333          grocery
# 14     crackers   156    535  0.291589          grocery
# 15     dressing   169   1151  0.146829          grocery
# 16        drink   170   1136  0.149648          grocery
# 17        flour    97    959  0.101147          grocery
# 18        fruit   524   1348  0.388724          grocery
# 19         gift   391    726  0.538567          grocery
# 20        grass   105    487  0.215606          grocery
# 21          gum   259    708  0.365819          grocery
# 22        honey   117    819  0.142857          grocery
# 23        jelly   185    837  0.221027          grocery
# 24        jerky   222    498  0.445783          grocery
# 25        juice   110    542  0.202952          grocery
# 26       keurig    92   1003  0.091725          grocery
# 27         milk   173    551  0.313975          grocery
# 28          mix    76    456  0.166667          grocery
# 29      noodles   120    682  0.175953          grocery
# 30         nuts   541   1637  0.330483          grocery
# 31      oatmeal    76    564  0.134752          grocery
# 32          oil   225   1738  0.129459          grocery
# 33         pack    95    454  0.209251          grocery
# 34        pasta   101    729  0.138546          grocery
# 35          pie   112    455  0.246154          grocery
# 36        plant   371    759  0.488801          grocery
# 37      popcorn   289    978  0.295501          grocery
# 38       powder   132    705  0.187234          grocery
# 39         rice    93    796  0.116834          grocery
# 40         salt   143    764  0.187173          grocery
# 41        sauce   181   1578  0.114702          grocery
# 42    seasoning   282   2229  0.126514          grocery
# 43        seeds    92    421  0.218527          grocery
# 44         soda   136    461  0.295011          grocery
# 45         soup   210    994  0.211268          grocery
# 46        sugar   335   1396  0.239971          grocery
# 47        syrup   208    870  0.239080          grocery
# 48          tea  1274   6739  0.189049          grocery
# 49         tuna   110    423  0.260047          grocery
# 50  unclustered  5599  21842  0.256341          grocery
# 51      vanilla   124    467  0.265525          grocery
# 52        water   246    685  0.359124          grocery
#
#                                               bad_set  \
# 0   items description content couldn reading expir...
# 1   properly picture mold spit description worse m...
# 2   crunchy severely change badly bent goods facto...
# 3                    horrible bite terrible packaging
# 4   bitter beware upset description maranatha real...
# 5   beware smashed bitter upset receiving arcor st...
# 6   overpriced strange changed shipment waste upda...
# 7   description rate wrong supposed threw changed ...
# 8   chinese wouldn selling supposed tasted dark gu...
# 9   total refund bother tiny throw bits waste mult...
# 10  stickers brown smashed receiving water spots s...
# 11  looked boxes disappointing description weak ca...
# 12  assuming weakest spilling sack exploded expire...
# 13  website poorly hopes smashed tasteless worse m...
# 14  cracked wrong looked hoping awful picture open...
# 15  total disgusting waste description awful stick...
# 16  overpriced date picture description expiration...
# 17                                  wasn label return
# 18  tasteless return refund poor pass edible cover...
# 19  reason brand rating learned purchasing terribl...
# 20                       disappointed sick disgusting
# 21  recipe sort literally remove sticky wouldn nas...
# 22                         threw return rock compared
# 23  lost overpriced broken wouldn original threw e...
# 24  reason decent description recipe entire nasty ...
# 25                           leaking wrong advertised
# 26
# 27  thailand white expired month today service ser...
# 28                              entire throw terrible
# 29  opened purchasing money terrible changed expec...
# 30  total sad avoid brown filled result receiving ...
# 31                                            changed
# 32  certified disappointment disappointing awful l...
# 33   wasn dents thought damaged horrible edible badly
# 34                                  months awful main
# 35  looked wouldn stale opened feel money bland te...
# 36  fact lesson stick hoped upset infested basical...
# 37  update poor shame write mistake previous remai...
# 38  label wouldn awful opened companies money fair...
# 39                                    burlap terrible
# 40                  waste crack positive powder wrong
# 41            waste return picture description refund
# 42  rating waste description refund apparently hor...
# 43                              dyed rancid dry grown
# 44  received excited change awful worse misleading...
# 45  portion changed mess wouldn mistake listed lis...
# 46  description disappointing worse mistake trash ...
# 47  description pictured fake watery buyer realize...
# 48  buyers poorly agreed tasteless altogether perf...
# 49  wasn awful received dented terrible couldn mus...
# 50  discarded responsibility destroyed resolve emb...
# 51  reason watered fine label description opened b...
# 52  sour dirty waste contact mistake nasty issue s...
#
#                                              good_set
# 0   eaten entire local bowl chips pure house regul...
# 1   selection pleased sweetened spirulina fills wa...
# 2   serving hot ship healthy prime veggies goodnes...
# 3   easiest hot set baking eaten son scratch effor...
# 4   rice peanutbutter alternative pleased hope bow...
# 5   coming kinds tend sick easter hooked colorful ...
# 6   purchasing total packages charges sweetened tr...
# 7   total set purchasing wine craving chips goodne...
# 8   makes minutes addition daily difference tapioc...
# 9   cooked school sauce knew veggies goodness stan...
# 10  drops stone school outer wine evening baby tob...
# 11  reason pleased nestle completely things warm s...
# 12  finest english gal printed breville shape snob...
# 13  purchasing dates hot pleased set warning doubl...
# 14  selection salty son potato bulk hold reorder s...
# 15  learned purchasing wine purse simple drizzle s...
# 16  times set fear purchasing cool weak user compl...
# 17  artisan sour serving blue packages purchasing ...
# 18  total bowl ship tastiest rice scones cal bread...
# 19  broadway hours young late style favorite recei...
# 20  switched bitter hot pleased dreamsicle price f...
# 21  hot pleased sweetened purchasing comparable to...
# 22  flu alternative learned purchasing regular cus...
# 23  bitter sweetened swedish slightly plum juice p...
# 24  addition things similar style jerkey sausage f...
# 25  serving alternative ship ocean normal note son...
# 26  invention oils opinion serving pleased metal s...
# 27  cooked traveling double bulk flavors goodness ...
# 28  serving versatile swedish purchasing called si...
# 29  ichiban set craving eaten son town surprisingl...
# 30  pasteurized learned craving chips steam servic...
# 31  hot pleased liquid set purchasing eaten switch...
# 32  drying stronger pleased wipe dinner son tin re...
# 33  opinion hot son prime bulk goodness brown cook...
# 34  cecco higher needed slightly onions nutrition ...
# 35  plum set easy case ingredients paste makes gue...
# 36  purchasing valentines true blossom prime hold ...
# 37  cooked alternative pleased set soft nuts drizz...
# 38  dates lack wine creamy goodness tasting slight...
# 39  ben serving opinion set purchasing life wanted...
# 40  bitter learned trace aroma sealed needed sligh...
# 41  stronger aloha alternative bowl weak double sa...
# 42  stronger alternative pleased dinner zip ethiop...
# 43  clean toasted sealed wanted break addition wro...
# 44  prime fizz addition coast sprite food slightly...
# 45  total chips ship son town ingredient today fla...
# 46  total blue sauce set muscovado costs smoothies...
# 47  son total shot wine bowl ship drizzle prime ar...
# 48  levels selection senses herbals schedule roobi...
# 49  items dinner guess glad spread treat eggs regu...
# 50  gal devon rep lungo petite difficulty reflux n...
# 51  drops pleased cupcakes chocolate oil slightly ...
# 52  shot purse convenient bring effective feels ar...

# %%
pd.concat([df,dff]).to_parquet('samples/reviews_key_topics.parquet', index=False)

# %%
ktops = pd.read_parquet('samples/reviews_key_topics.parquet')

# %%
import os, calendar, pandas as pd, dask
from dask.distributed import Client
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:59870' processes=4 threads=8, memory=15.72 GiB>

# %%
files = [i for i in os.listdir('samples/labeled_samples_v2/')]

# %%
get_monthly_review_counts('apparel_clustered_embeddings.parquet')
# Out:
#          labels  January  February  March  April   May  June  July  August  \
# 0          baby      171       168    177    155   166   165   169     151
# 1           bag       81        71     76     62    76    55    82      93
# 2          belt      165       137    170    156   161   156   161     166
# 3           bra      399       386    441    437   449   536   530     489
# 4       costume      277       196    191    185   148   159   164     218
# 5         dress      633       683    912   1073  1031   979   980     978
# 6        girls'       98        81     89     73    81    55    79      72
# 7        gloves      241       180    125     84    64    43    49      39
# 8           hat      585       468    434    415   394   462   434     404
# 9        hoodie       90        62     63     33    50    38    35      40
# 10       jacket      746       486    435    370   274   225   195     207
# 11        jeans      343       251    312    241   239   193   202     192
# 12     leggings      194       129    117     99    92   100    70      75
# 13          men      136       112    107    133   129   150   142     141
# 14      pajamas       85        47     42     32    36    41    56      27
# 15        pants      491       383    473    491   511   558   565     482
# 16         robe      176       110    116     66   103    82    76      84
# 17        scarf      267       177    160    115   103    74    77      76
# 18        scrub       46        48     70     60    67    50    56      59
# 19        shirt     1448      1087   1230   1074  1182  1224  1312    1315
# 20        skirt      103       119    141    140   147   125   149     128
# 21        socks      582       385    352    333   332   297   289     267
# 22     swimsuit      100       110    210    236   323   321   339     188
# 23          tie       68        49     75     69    55    76    48      63
# 24  unclustered     2104      1708   1926   1826  1841  1841  1785    1715
# 25        waist      130       142    211    174   163   131   154     154
# 26       wallet      201       174    196    161   166   174   202     178
# 27          wig       52        40     50     41    41    41    39      41
# 28        women      315       270    350    321   314   302   341     296
#
#     September  October  November  December product_category
# 0          92      145       155       177          apparel
# 1          44       59        51        51          apparel
# 2         103      105       105       144          apparel
# 3         285      276       269       310          apparel
# 4         230      834       623       453          apparel
# 5         435      469       480       624          apparel
# 6          38       70        73       119          apparel
# 7          32       75       131       209          apparel
# 8         231      307       372       559          apparel
# 9          25       54        61       110          apparel
# 10        181      332       550       820          apparel
# 11        150      174       220       287          apparel
# 12         57       93       135       192          apparel
# 13         84      100        93       118          apparel
# 14         28       40        54       105          apparel
# 15        309      323       348       427          apparel
# 16         61       69       116       148          apparel
# 17         51       69       147       301          apparel
# 18         50       26        38        44          apparel
# 19        605      789       899      1397          apparel
# 20         58       68        58        82          apparel
# 21        187      271       358       506          apparel
# 22         63       45        49        54          apparel
# 23         45       46        56        95          apparel
# 24       1023     1313      1467      2078          apparel
# 25         66      126        92       118          apparel
# 26        108      130       133       187          apparel
# 27         32      106        99        78          apparel
# 28        155      181       186       265          apparel

# %%
def get_monthly_review_counts(file):
    name = file.replace('_clustered_embeddings.parquet','').replace('_',' ')
    df = pd.read_parquet(f'samples/labeled_samples_v2/{file}')
    df.review_date = pd.to_datetime(df.review_date)
    df['month'] = df.review_date.dt.month
    x = {}
    for group in df.groupby('labels'):
        x[group[0]] = group[1].month.value_counts()
    df = pd.DataFrame(x).T.reset_index().rename(
        columns={'index':'labels'}).rename(
            columns=dict(zip([i+1 for i in range(12)
            ], calendar.month_name[:][1:])))
    df['product_category'] = name
    return df

# %%
tasks = [dask.delayed(get_monthly_review_counts)(file) for file in files]

# %%
tasks_list = dask.delayed()(tasks)

# %%
results = tasks_list.compute()

# %%
pd.concat(results).to_parquet('samples/monthly_review_counts.parquet', index=False)
# Out:
# C:\Users\E079051\AppData\Local\Programs\Python\Python39\lib\statistics.py:168: RuntimeWarning: overflow encountered in long_scalars
#   partials[d] = partials_get(d, 0) + n

# %%
df = pd.read_parquet('samples/labeled_samples_v3/apparel_clustered_embeddings.parquet')

# %%
df.head()
# Out:
#    customer_id       review_id  product_id  product_parent  \
# 0     15235042  R21ENC85KLYCRX  B000MX94XE       908407169
# 1     44050726   RZ3AYDOBNL9UF  B00IFE539G       802216157
# 2     13234601  R2UR25346UG5M1  B00NBFGR8U       727214648
# 3      3377308   R8OKJGCCG0GQT  B00KFEFK8S       223324092
# 4      6438794   RXSGXNTAR5Y7M  B00368CL9Q       387289369
#
#                                        product_title  star_rating  \
# 0   Bali Women's Skimp Skamp Brief Panty Number 2633            5
# 1              PLUS SIZE MAXI PAISLEY SURPLICE DRESS            3
# 2  EASY Women's Retro Vintage Punk plus size Ripp...            1
# 3  Vikoros Waist Tummy Slimming Body Shapewear Be...            5
# 4            Shock Absorber Women's Ultimate Run Bra            5
#
#    helpful_votes  total_votes vine verified_purchase review_date  \
# 0              1            1    N                 Y  2011-08-26
# 1              3            4    N                 Y  2014-06-14
# 2              1            1    N                 Y  2015-06-23
# 3              2            2    N                 Y  2015-04-10
# 4              1            1    N                 Y  2015-01-29
#
#                                               review        e1        e2  \
# 0  Best granny panties ever These panties are so ... -3.855251 -0.202959
# 1  Okay This is a nice dress. This just is not fo...  0.464726 -0.655830
# 2  sizes to do match i ordered a large and got a ... -3.098939  2.540366
# 3  Perfect fit give you shape flatten your tummy ... -3.208839 -2.014310
# 4  Great bra for exercise. This is a great bra! I... -5.507154 -1.545273
#
#    clusters       labels product_category
# 0        19        women          apparel
# 1        14        dress          apparel
# 2        -1  unclustered          apparel
# 3        18        waist          apparel
# 4         4          bra          apparel

# %%
apparel = ktops[ktops.product_category=='apparel']

# %%
apparel
# Out:
#          labels   bad   good   ranking product_category  \
# 0          baby   430   1461  0.294319          apparel
# 1           bag   198    603  0.328358          apparel
# 2          belt   591   1138  0.519332          apparel
# 3           bra  1623   3184  0.509736          apparel
# 4       costume  1088   2590  0.420077          apparel
# 5         dress  2719   6558  0.414608          apparel
# 6        girls'   216    712  0.303371          apparel
# 7        gloves   379    893  0.424412          apparel
# 8           hat  1193   3872  0.308110          apparel
# 9        hoodie   162    499  0.324649          apparel
# 10       jacket  1281   3540  0.361864          apparel
# 11        jeans   847   1957  0.432805          apparel
# 12     leggings   477    876  0.544521          apparel
# 13          men   406   1039  0.390760          apparel
# 14      pajamas   157    436  0.360092          apparel
# 15        pants  1666   3695  0.450880          apparel
# 16         robe   245    962  0.254678          apparel
# 17        scarf   376   1241  0.302981          apparel
# 18        scrub   134    480  0.279167          apparel
# 19        shirt  4111   9451  0.434980          apparel
# 20        skirt   397    921  0.431053          apparel
# 21        socks  1239   2920  0.424315          apparel
# 22     swimsuit   644   1394  0.461980          apparel
# 23          tie   149    596  0.250000          apparel
# 24  unclustered  6024  14603  0.412518          apparel
# 25        waist   508   1153  0.440590          apparel
# 26       wallet   492   1518  0.324111          apparel
# 27          wig   216    444  0.486486          apparel
# 28        women  1105   2191  0.504336          apparel
#
#                                               bad_set  \
# 0   poorly rough ripped thinner stitching suspende...
# 1   ripped falling useless coming broke poor broke...
# 2   digs fray pin sending home crap disappointing ...
# 3   ahh twisted madonna lying meh factor beware un...
# 4   practically refund junk sending sags god edge ...
# 5   deceiving frayed greatest poor oddly practical...
# 6   description poor return waste ripped paid seam...
# 7   poorly rip refund mail poor ripped holding thi...
# 8   alright paint uneven weren poorly envelope sta...
# 9   return xxl poor completely wouldn child wrong ...
# 10  biggest false passed horrible stitches defect ...
# 11  sides terrible possibly awful disappointment p...
# 12  poorly rip faux poor pill pic thinner version ...
# 13  items aware pictured labeled original reading ...
# 14  velcro sleeves return shrunk children cheap cr...
# 15  tailoring patch incorrect reach sending reorde...
# 16  poorly shoulder thicker poor rough ran fuzz sc...
# 17  poorly terrible careful spend flimsy poor dama...
# 18  returning pay return wide chest returned send ...
# 19  deceiving twisted respond worker included tras...
# 20  hassle disappointment advertised shrunk poor p...
# 21  covered baggy yarn inch missing defective undo...
# 22  deceiving poor items poorly ripped wash listed...
# 23  correct return disappointing inside wouldn fel...
# 24  deceiving improve dissatisfied deceptive worth...
# 25  ripped prior regret proper stuck meant cotton ...
# 26  poorly worst stuffed undone damaged falls effo...
# 27  sides child worst model pic funny event luck e...
# 28  corset boob crap warned disappointing moved ho...
#
#                                              good_set
# 0   amazing carters family careful thinking beauti...
# 1   amazing idea easier contents construction plan...
# 2   amazing personally plenty surprise cell catch ...
# 3   blouses heaven duty yay subtle smart expectati...
# 4   expectations dirty warned preferred nicer gart...
# 5   sunday fullness proper familiar slutty early o...
# 6   amazing awesome monster summer durable person ...
# 7   dirty stuff bunch arrive clothing tablet sligh...
# 8   dirty surgery silk activities faux purchases w...
# 9   amazing higher shipped chest live looked satis...
# 10  definately bib dirty preferred warned tank har...
# 11  shrank walk expectations shipped lady legged p...
# 12  amazing pregnancy set fashion capris summer pi...
# 13  amazing washings silk traditional hot chaffing...
# 14  clothes lot beautiful durable looked choose wa...
# 15  protect heaven preferred mart surgery field pr...
# 16  amazing online luxurious perfectly left skin p...
# 17  amazing told throw perfectly aren olive clothe...
# 18  sides suggest body favorite looked floor wears...
# 19  excessive outfits reversible tapered pregnancy...
# 20  amazing staple tank nicer shipped beautifully ...
# 21  amazing surgery silk concern pricey measuremen...
# 22  vibrant washing avoid personally shipped dress...
# 23  amazing easier links high darker hang accessor...
# 24  gum outfits humid pointed tommy heaven curious...
# 25  understand walk pregnancy tank expectations sh...
# 26  dirty expectations shipped bonus coupons lovel...
# 27  convention opened curl realistic fast fantasti...
# 28  child working repeat nicer expectations shippe...

# %%
ktops[ktops.product_category=='apparel'].labels.unique()
# Out:
# array(['baby', 'bag', 'belt', 'bra', 'costume', 'dress', "girls'",
#        'gloves', 'hat', 'hoodie', 'jacket', 'jeans', 'leggings', 'men',
#        'pajamas', 'pants', 'robe', 'scarf', 'scrub', 'shirt', 'skirt',
#        'socks', 'swimsuit', 'tie', 'unclustered', 'waist', 'wallet',
#        'wig', 'women'], dtype=object)

# %%
df.product_category.unique()[0]
# Out:
# 'apparel'

# %%
def get_bad_subset(df, label):
    bad_words = ktops[(ktops.labels==label)].bad_set.iloc[0].split()
    return df[df.review.apply(lambda x: any(
        i in x for i in bad_words)) & (df.star_rating <= 3) & (df.labels==label)]

# %%
# %%time
dfs = []
for label in df.labels.unique().tolist():
    dfs.append(get_bad_subset(df, label))
# Out:
# CPU times: total: 1min 7s
# Wall time: 1min 8s

# %%
bad_reviews = pd.concat(dfs)

# %%
def get_good_subset(df, label):
    return df[df.review.apply(lambda x: any(
        i in x for i in ktops.good_set.iloc[0].split())) & \
            (df.star_rating > 3) & (df.labels==label)]

# %%
# %%time
dfs2 = []
for label in df.labels.unique().tolist():
    dfs2.append(get_good_subset(df, label))
# Out:
# CPU times: total: 1min 6s
# Wall time: 1min 7s

# %%
good_reviews = pd.concat(dfs2)

# %%
bad_reviews[bad_reviews.review.duplicated(keep=False)].review.iloc[0]
# Out:
# "Warning WARNING to future buyers!!!!!. Everything could be okay if the seller posted information on the composition of the fabric: 65% polyester and 35 rayon. Misleading description and the initial price before the reduction suggesting 140s wool, and this is only the name of its own suit. Unfortunately, I've been caught, and worse, from Europe and bought two suits shipping cost me $ 99 and even tax. I was hoping that I get a good quality suits, and received sewn from no natural materials. Next time I will be more rigorous and carefully inquired about the goods a seller."

# %%
ktops.good_set.iloc[0]
# Out:
# 'amazing carters family careful thinking beautiful future told superb husband guy excellent customer parents nights target pool chest sweet continue prefer strong comfy hit children slightly functional fantastic scratch walk'

# %%
tasks = [dask.delayed(get_subset)(df,'apparel', label) for label in df.labels.unique().tolist()]

# %%
tasks_list = dask.delayed()(tasks)

# %%
results = tasks_list.compute()

# %%
'Rating: ' + bad_reviews.star_rating.astype(str) + ' ' + \
    'Title: ' + bad_reviews.product_title.astype(str) + ' ' + \
        'Review: ' + bad_reviews.review
# Out:
# 161      Rating: 1 Title: Underworks Post Delivery Belt...
# 165      Rating: 2 Title: Fruit of the Loom Women's 6-P...
# 274      Rating: 2 Title: Women's Daywear Stretch Slim ...
# 827      Rating: 1 Title: Hanes Women's Cotton Brief Pa...
# 1070     Rating: 1 Title: Fruit of the Loom Women's 3 P...
#                                ...
# 93715    Rating: 1 Title: Grey & White Plaid Flannel Me...
# 95710    Rating: 1 Title: LED Light Review: Absolute Ga...
# 96132    Rating: 1 Title: Carter's Watch the Wear Hoode...
# 97316    Rating: 1 Title: Nickelodeon Paw Patrol Little...
# 99627    Rating: 1 Title: Cookie Monster Cookie Power S...
# Length: 9456, dtype: object

# %%
bad_reviews.to_parquet('apparel_bad_reviews.parquet', index=False)
good_reviews.to_parquet('apparel_good_reviews.parquet', index=False)

# %%
def add_cats(file):
    name = file.replace('_clustered_embeddings.parquet','').replace('_',' ')
    df = pd.read_parquet(f'samples/labeled_samples_v2/{file}')
    df['product_category'] = name
    df.to_parquet(f'samples/labeled_samples_v3/{file}', index=False)

# %%
files = [i for i in os.listdir('samples/labeled_samples_v3/')]

# %%
tasks = [dask.delayed(add_cats)(file) for file in files]

# %%
dask.delayed()(tasks).compute()
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
dff = pd.read_parquet('samples/labeled_samples_v3/wireless_clustered_embeddings.parquet')

# %%
dff
# Out:
#        customer_id       review_id  product_id  product_parent  \
# 0         26129696   RN1NJ4UU01IEY  B0085EXLWW       269963285
# 1         12852326  R16Y9IZE9UHBTL  B001S2R8TU       964300755
# 2         51557291  R364C9RG4C582B  B00QMPY77E       709352186
# 3         33833896  R1HDB0MSI8MB7Y  B00NGNQ47G       419068635
# 4         22125670   RBGN2ZEND2PYT  B00C96CMDG       124792632
# ...            ...             ...         ...             ...
# 99995     12306293  R1L8HVLZE2G8KT  B00MOEFZQO       133246919
# 99996     31869696  R1ULPKRSE7DPI8  B00SXFEA9Q       438471763
# 99997      1684377  R3IV7OIU1V447E  B00EC4WJPY       348670033
# 99998     16773961  R2I3Y050XE096Y  B0099I81IM        98128275
# 99999     18200004  R15QV0UOC4RRUX  B00K80DZ7C       387538081
#
#                                            product_title  star_rating  \
# 0      Apple 30 Pin USB Cable EZOPower CERTIFIED 6 Fe...            5
# 1                 Sony 4/3/2-Channel ZR-Series Amplifier            5
# 2      iPhone 6 Battery Case , Maxboost VIVID iPhone ...            5
# 3      iPhone 6S Plus Case, Terrapin Trendy [Studded]...            5
# 4      Samsung Galaxy S4 Case - OtterBox Defender Ser...            5
# ...                                                  ...          ...
# 99995  iPhone SE Case, iPhone 5S Case, Shieldon Genui...            5
# 99996  UAG Samsung Galaxy S6 [5.1-inch screen] Feathe...            5
# 99997  Hot Sale! Z-Design Beautiful Personality& Crea...            2
# 99998              URBAN ARMOR GEAR Case for iPhone 5/5S            4
# 99999  IMRIS - Iphone 5s Charger. #1 Iphone 5s, 5c, 5...            1
#
#        helpful_votes  total_votes vine verified_purchase review_date  \
# 0                  1            1    N                 Y  2014-09-23
# 1                  1            1    N                 Y  2012-01-17
# 2                  1            1    N                 Y  2015-07-14
# 3                  3            5    N                 Y  2014-11-26
# 4                  1            1    N                 Y  2013-12-07
# ...              ...          ...  ...               ...         ...
# 99995              1            1    N                 Y  2015-01-07
# 99996             30           32    N                 Y  2015-04-11
# 99997              1            1    N                 Y  2014-06-10
# 99998              2            3    N                 Y  2013-02-02
# 99999              7            7    N                 Y  2014-07-15
#
#                                                   review         e1  \
# 0      Five Stars Works well so far, cheaper then app...  12.904141
# 1      Great for 4 6x9's This amp sounded so good tha...  17.273903
# 2      I've ordered battery cases before and have bee...   9.899235
# 3      Absolutely fantastic!! I am so thrilled to hav...   5.748475
# 4      Excellent protection for your Galaxy S4 The Ot...   3.808937
# ...                                                  ...        ...
# 99995  Just what I was looking for Loving the case so...   5.980806
# 99996  Another great UAG case Typical UAG case perfec...   2.869984
# 99997  Fair The case is nice but it's starting to com...   5.443238
# 99998  GREAT CUSTOMER SERVICE Loved everything about ...   3.921398
# 99999  DO NOT BUY Got this item after weeks of waitin...  12.984593
#
#               e2  clusters       labels product_category
# 0       5.880183        26        cable         wireless
# 1      10.866034         7     speakers         wireless
# 2       4.354083        21         case         wireless
# 3      11.434567        33         case         wireless
# 4       9.236429        30         case         wireless
# ...          ...       ...          ...              ...
# 99995  11.558444        33         case         wireless
# 99996  10.604469        -1  unclustered         wireless
# 99997  10.432199        39         case         wireless
# 99998   9.913481        -1  unclustered         wireless
# 99999   5.335047        26        cable         wireless
#
# [100000 rows x 17 columns]

# %% [markdown]
# ---

# %%
from get_reviews_deprecated import get_reviews_having_keywords

# %%
bad_reviews, good_reviews = get_reviews_having_keywords('apparel_clustered_embeddings.parquet')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 bad_reviews, good_reviews = get_reviews_having_keywords('apparel_clustered_embeddings.parquet')
#
# File c:\Users\E079051\Desktop\Product_Reviews_Analysis\get_reviews.py:33, in get_reviews_having_keywords(file)
#      29         good_words = ktops[ktops.labels==label].good_set.iloc[0].split()
#      30         bad_reviews.append(df[df.review.apply(
#      31             lambda x: any(i in x for i in bad_words) & \
#      32             (df.star_rating <= 3) & (df.labels==label))])
# ---> 33         good_reviews.append(df[df.review.apply(
#      34             lambda x: any(i in x for i in good_words) & \
#      35             (df.star_rating > 3) & (df.labels==label))])
#      37 bad_reviews = pd.concat(bad_reviews).review.drop_duplicates(inplace=True)
#      38 good_reviews = pd.concat(good_reviews).review.drop_duplicates(inplace=True)
#
# File c:\Users\E079051\Desktop\Product_Reviews_Analysis\venv\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\E079051\Desktop\Product_Reviews_Analysis\venv\lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File c:\Users\E079051\Desktop\Product_Reviews_Analysis\venv\lib\site-packages\pandas\core\apply.py:1165, in SeriesApply.apply_standard(self)
#    1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
# -> 1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#    1166 else:
#    1167     return obj._constructor(mapped, index=obj.index).__finalize__(
#    1168         obj, method="apply"
#    1169     )
#
# File c:\Users\E079051\Desktop\Product_Reviews_Analysis\venv\lib\site-packages\pandas\core\frame.py:753, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     744         columns = ensure_index(columns)
#     745     arrays, columns, index = nested_data_to_arrays(
#     746         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     747         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     751         dtype,
#     752     )
# --> 753     mgr = arrays_to_mgr(
#     754         arrays,
#     755         columns,
#     756         index,
#     757         dtype=dtype,
#     758         typ=manager,
#     759     )
#     760 else:
#     761     mgr = ndarray_to_mgr(
#     762         data,
#     763         index,
#    (...)
#     767         typ=manager,
#     768     )
#
# File c:\Users\E079051\Desktop\Product_Reviews_Analysis\venv\lib\site-packages\pandas\core\internals\construction.py:154, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     151 axes = [columns, index]
#     153 if typ == "block":
# --> 154     return create_block_manager_from_column_arrays(
#     155         arrays, axes, consolidate=consolidate
#     156     )
#     157 elif typ == "array":
#     158     return ArrayManager(arrays, [index, columns])
#
# File c:\Users\E079051\Desktop\Product_Reviews_Analysis\venv\lib\site-packages\pandas\core\internals\managers.py:2196, in create_block_manager_from_column_arrays(arrays, axes, consolidate)
#    2179 def create_block_manager_from_column_arrays(
#    2180     arrays: list[ArrayLike],
#    2181     axes: list[Index],
#    (...)
#    2192     # These last three are sufficient to allow us to safely pass
#    2193     #  verify_integrity=False below.
#    2195     try:
# -> 2196         blocks = _form_blocks(arrays, consolidate)
#    2197         mgr = BlockManager(blocks, axes, verify_integrity=False)
#    2198     except ValueError as e:
#
# File c:\Users\E079051\Desktop\Product_Reviews_Analysis\venv\lib\site-packages\pandas\core\internals\managers.py:2270, in _form_blocks(arrays, consolidate)
#    2267 if issubclass(dtype.type, (str, bytes)):
#    2268     dtype = np.dtype(object)
# -> 2270 values, placement = _stack_arrays(list(tup_block), dtype)
#    2271 if is_dtlike:
#    2272     values = ensure_wrapped_if_datetimelike(values)
#
# File c:\Users\E079051\Desktop\Product_Reviews_Analysis\venv\lib\site-packages\pandas\core\internals\managers.py:2311, in _stack_arrays(tuples, dtype)
#    2309 stacked = np.empty(shape, dtype=dtype)
#    2310 for i, arr in enumerate(arrays):
# -> 2311     stacked[i] = arr
#    2313 return stacked, placement
#
# KeyboardInterrupt:

# %%
def take_sample(file):
    df = pd.read_parquet(f'samples/labeled_samples_v3/{file}')
    df = df[df.clusters!=-1]
    bad = df[df.star_rating <= 3]
    bad = bad.sample(min(5000,bad.shape[0]), random_state=1729)
    good = df[df.star_rating > 3]
    good = good.sample(min(5000,good.shape[0]), random_state=1729)

    bad['text'] = 'Rating: ' + bad.star_rating.astype(str) + ', ' + \
        'Title: ' + bad.product_title.astype(str) + ', ' + \
            'Review: ' + bad.review

    good['text'] = 'Rating: ' + good.star_rating.astype(str) + ', ' + \
        'Title: ' + good.product_title.astype(str) + ', ' + \
            'Review: ' + good.review

    return bad[['product_category','labels','text']], good[['product_category','labels','text']]

# %%
import os, calendar, pandas as pd, dask
from dask.distributed import Client
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:61311' processes=4 threads=8, memory=15.72 GiB>

# %%
files = [i for i in os.listdir('samples/labeled_samples_v3/')]

# %%
tasks = [dask.delayed(take_sample)(file) for file in files]

# %%
results = dask.delayed()(tasks).compute()

# %%
pd.concat([x[0] for x in results]).to_parquet('samples/bad_reviews.parquet', index=False)
pd.concat([x[1] for x in results]).to_parquet('samples/good_reviews.parquet', index=False)

# %%
pd.concat([x[0] for x in results])
# Out:
#       product_category    labels  \
# 59154          apparel     shirt
# 37170          apparel    jacket
# 72333          apparel     dress
# 5495           apparel    wallet
# 7341           apparel     dress
# ...                ...       ...
# 89036         wireless   battery
# 1494          wireless   charger
# 3282          wireless       usb
# 69880         wireless  speakers
# 33270         wireless      case
#
#                                                     text
# 59154  Rating: 2, Title: Star Trek Starfleet Uniform ...
# 37170  Rating: 2, Title: Baihong Men's Military Style...
# 72333  Rating: 1, Title: Women's 2-in-1 Dress with bu...
# 5495   Rating: 1, Title: YCM0201 Mens Magic Wallet Cr...
# 7341   Rating: 3, Title: Women's Plus Size Off Should...
# ...                                                  ...
# 89036  Rating: 2, Title: Zerolemon Travel External Ba...
# 1494   Rating: 2, Title: Anker 40W 5-Port Family-Size...
# 3282   Rating: 1, Title: kwmobile micro USB dockingst...
# 69880  Rating: 2, Title: Boss AR2600.2 ARMOR 2-Channe...
# 33270  Rating: 1, Title: AGPtek Silver Ultra-thin Pro...
#
# [180238 rows x 3 columns]
